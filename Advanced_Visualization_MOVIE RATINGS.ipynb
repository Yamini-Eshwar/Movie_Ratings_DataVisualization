# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\vamsi\Downloads\Movie-Rating.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.isnull().sum()
# Out:
# Film              0
# Genre             0
# CriticRating      0
# AudienceRating    0
# BudgetMillions    0
# Year              0
# dtype: int64

# %%
movies.describe()
# if you look at the year dat type is int64, and its calculating mean value for year which is meaningless
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
#How to working with joint plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')
plt.show()

# %%
j = sns.jointplot(data=movies, x= 'CriticRating', y = 'AudienceRating', kind= 'hex', height=5)
plt.show()

# %%
#Auidence ratings are more generally high, where as Critc ratings areuniformly distributed

# %%
m1  = sns.distplot(movies.AudienceRating)
plt.show()

# %%
#Auidences mostly rating between mid to high values

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(movies.AudienceRating, bins=15)
plt.show()  # here seaborn giving you smooth curve where as normal hist wont

# %%
plt.hist(movies.AudienceRating, bins=15)
plt.show()

# %%
plt.hist(movies.CriticRating, bins=15) #uniform distribution
plt.show()

# %%
plt.hist(movies['BudgetMillions'])
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMillions)
plt.show()  
#It creates a histogram of movie budget but only for Adventure

# %%
#Below plots are stacked histogram beacuse overlapped
#Filters Budget for Action, comedy, drama

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=20)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,
         movies[movies.Genre == 'Comedy'].BudgetMillions,  
         movies[movies.Genre == 'Drama'].BudgetMillions], 
         bins=20, stacked=True)
plt.show()

# %%
for i in movies.Genre.cat.categories:
    print(i)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.lmplot(data=movies, x='CriticRating',y='AudienceRating', fit_reg=False)
plt.show()

# %%
sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue= 'Genre')
plt.show()  #colors each point based on its Genre

# %%
sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue='Genre', height=10, aspect=1)
plt.show()

# %%
#Kernal Density Plot

# %%
sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating)
plt.show()

# %%
sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating,cmap='Reds')
plt.show()

# %%
sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating,cmap='Greens_r')
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))
plt.show()       #1row,2col

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))

k1 = sns.kdeplot(x= movies.BudgetMillions, y = movies.AudienceRating, ax=ax[0], figsize=(5,6))
k2 = sns.kdeplot(x= movies.BudgetMillions, y = movies.CriticRating, ax=ax[1], figsize=(5,6))

plt.show()

# %%
#Box plots

w =sns.boxplot(data=movies, x='Genre', y = 'CriticRating')
plt.show()

# %%
#Violin plot

z= sns.violinplot(data=movies, x='Genre', y='CriticRating')
plt.show()

# %%
sns.boxplot(data=movies [movies.Genre == 'Action'], x='Year', y='CriticRating')

plt.show()

# %%
sns.FacetGrid(movies, row='Genre', col = 'Year', hue= 'Genre')

plt.show()
